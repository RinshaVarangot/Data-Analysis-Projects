# %% [markdown]
# # Titanic Survival Prediction using Machine Learning and Exploratory Data Analysis

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df=pd.read_excel(r"C:\Users\Admin\Documents\GitHub\Python-Project\Titanic Survival\Titanic Dataset.xlsx")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Missing Value Analysis
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='Blues')

plt.title(
"Missing Values"
)
# Out:
# Text(0.5, 1.0, 'Missing Values')

# %% [markdown]
# **This code creates a missing values heatmap to visually identify where null (missing) values exist in your dataset.**
#
# Age contains missing values.
#
# Cabin heavily missing.
#
# Embarked few missing.

# %%
#Drop Cabin (too many missing), PassengerId, Ticket (low usefulness)
df.drop(['Ticket','Cabin',],axis=1,inplace=True)

# %% [markdown]
# **PassengerId → Dropped because it is only an ID number and does not help predict survival,Machine Learning models usually do not benefit from ID columns.**
#
# **Ticket → Dropped because ticket numbers usually do not provide useful information for the model.**
#
# **Cabin → Dropped because it contains many missing (null) values.**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna(value='S')

# %% [markdown]
# **Why 'S'?**
#
# **S appears most frequently, so replacing missing values with 'S' is a common preprocessing technique.**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         0
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# **S = Southampton**
#
# **C = Cherbourg**
#
# **Q = Queenstown**

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Pclass',y='Age',hue='Pclass',data=df,palette='Blues')
plt.show()

# %% [markdown]
# **Fill missing Age values using Passenger Class information instead of dropping rows.**

# %%
def impute_age(cols):
    Age=cols['Age']
    Pclass=cols['Pclass']
    
    if pd.isnull(Age):
        if Pclass==1:
            return 37
        elif Pclass==2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
df['Age'] = df[['Age','Pclass']].apply(impute_age,axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked
# 0      0   7.2500        S
# 1      0  71.2833        C
# 2      0   7.9250        S
# 3      0  53.1000        S
# 4      0   8.0500        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch   Fare Embarked
# 886    male  27.0      0      0  13.00        S
# 887  female  19.0      0      0  30.00        S
# 888  female  24.0      1      2  23.45        S
# 889    male  26.0      0      0  30.00        C
# 890    male  32.0      0      0   7.75        Q

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **Create a new useful feature (Title) from Name to improve Machine Learning prediction. This is called Feature Engineering.**

# %%
# Extract title from passenger name
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# Check extracted titles
print(df['Title'].value_counts())
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
## Replace rare titles
df['Title'] = df['Title'].replace(
['Lady','Countess','Capt','Col','Don','Dr',
'Major','Rev','Sir','Jonkheer','Dona'],
'Rare'
)

# Standardize Miss/Ms/Mlle and Mrs/Mme
df['Title'] = df['Title'].replace(
['Mlle','Ms'],
'Miss'
)

df['Title'] = df['Title'].replace(
'Mme',
'Mrs'
)

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr        517
# Miss      185
# Mrs       126
# Master     40
# Rare       23
# Name: count, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked Title
# 0      0   7.2500        S    Mr
# 1      0  71.2833        C   Mrs
# 2      0   7.9250        S  Miss
# 3      0  53.1000        S   Mrs
# 4      0   8.0500        S    Mr

# %%
# Drop Name
df.drop("Name",axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked Title
# 0        S    Mr
# 1        C   Mrs
# 2        S  Miss
# 3        S   Mrs
# 4        S    Mr

# %% [markdown]
# **FamilyStatus to identify whether a passenger was traveling alone or with family.**

# %%
df['FamilyStatus']=df.apply(lambda row:'Alone' if(row['SibSp']==0 and row['Parch']==0) else "Family",axis=1)

# %%
df['FamilyStatus'].value_counts()
# Out:
# FamilyStatus
# Alone     537
# Family    354
# Name: count, dtype: int64

# %% [markdown]
# **FareBand feature by dividing the Fare column into 4 equal-sized bins (quartiles):**

# %%
df['FareBand']=pd.qcut(
df['Fare'],
4
)

# %%
df['FareBand']
# Out:
# 0       (-0.001, 7.91]
# 1      (31.0, 512.329]
# 2       (7.91, 14.454]
# 3      (31.0, 512.329]
# 4       (7.91, 14.454]
#             ...
# 886     (7.91, 14.454]
# 887     (14.454, 31.0]
# 888     (14.454, 31.0]
# 889     (14.454, 31.0]
# 890     (-0.001, 7.91]
# Name: FareBand, Length: 891, dtype: category
# Categories (4, interval[float64, right]): [(-0.001, 7.91] < (7.91, 14.454] < (14.454, 31.0] < (31.0, 512.329]]

# %%
df['FareBand'].value_counts()
# Out:
# FareBand
# (7.91, 14.454]     224
# (-0.001, 7.91]     223
# (14.454, 31.0]     222
# (31.0, 512.329]    222
# Name: count, dtype: int64

# %% [markdown]
# **creating a new feature (AgeGroup) from an existing feature (Age).**

# %%
df['AgeGroup']=pd.cut(
df['Age'],
bins=[0,12,18,35,60,100],

labels=[
'Child',
'Teen',
'Adult',
'MiddleAge',
'Senior'
]
)

# %%
df['AgeGroup'].value_counts()
# Out:
# AgeGroup
# Adult        505
# MiddleAge    225
# Teen          70
# Child         69
# Senior        22
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked Title FamilyStatus         FareBand   AgeGroup
# 0        S    Mr       Family   (-0.001, 7.91]      Adult
# 1        C   Mrs       Family  (31.0, 512.329]  MiddleAge
# 2        S  Miss        Alone   (7.91, 14.454]      Adult
# 3        S   Mrs       Family  (31.0, 512.329]      Adult
# 4        S    Mr        Alone   (7.91, 14.454]      Adult

# %%
df.to_excel('cleaned_Titanic_Dataset.xlsx')

# %% [markdown]
# ## EDA

# %%
df=pd.read_excel('cleaned_Titanic_Dataset.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0           0            1         0       3    male  22.0      1      0
# 1           1            2         1       1  female  38.0      1      0
# 2           2            3         1       3  female  26.0      0      0
# 3           3            4         1       1  female  35.0      1      0
# 4           4            5         0       3    male  35.0      0      0
#
#       Fare Embarked Title FamilyStatus         FareBand   AgeGroup
# 0   7.2500        S    Mr       Family   (-0.001, 7.91]      Adult
# 1  71.2833        C   Mrs       Family  (31.0, 512.329]  MiddleAge
# 2   7.9250        S  Miss        Alone   (7.91, 14.454]      Adult
# 3  53.1000        S   Mrs       Family  (31.0, 512.329]      Adult
# 4   8.0500        S    Mr        Alone   (7.91, 14.454]      Adult

# %% [markdown]
# ## Univeariate Analysis-Numerical

# %%
num_cols=['Age','Fare','SibSp','Parch']

for col in num_cols:

    plt.figure()

    sns.histplot(
    df[col],
    kde=True
    )

    plt.title(
    f"Distribution of {col}"
    )

    plt.show()

# %% [markdown]
# **Majority of passengers were adults, with fewer elderly passengers onboard.**
#
# **Most passengers traveled with lower ticket fares, while only a small number paid premium fares.**
#
# **Most passengers traveled alone or with a small family group.Large family groups were uncommon.**
#
# **The majority of passengers traveled without parents or children.Fewer passengers traveled with family members.**

# %% [markdown]
# ## Univariate Analysis - Categorical

# %%
cat_cols = ['Survived','Sex','Embarked','Title','Pclass']

for col in cat_cols:
    plt.figure(figsize=(8,4))
    df[col].value_counts().head(10).plot(kind='bar')
    plt.title(f"Top Categories in {col}")
    plt.show()

# %% [markdown]
# **More passengers did not survive than survived.**
#
# **Male passengers were higher than female passengers.**
#
# **Most passengers boarded from Southampton (S).Cherbourg (C) and Queenstown (Q) had fewer passengers.**
#
# **'Mr' was the most common title.'Miss' and 'Mrs' followed.Rare titles appeared very less frequently.**
#
# **Most passengers belonged to Third Class.First Class passengers were comparatively fewer.**

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.countplot(
x='Sex',hue='Survived',data=df,palette='Blues')

plt.title("Gender vs Survival")


plt.show()

# %%
survival_gender=df.groupby('Sex')['Survived'].value_counts()

# %%
survival_gender
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %% [markdown]
# **Female survival rate higher.**

# %%
sns.countplot(
x='Pclass',hue='Survived',data=df,palette='Blues')

plt.title("Passenger Class vs Survival")


plt.show()

# %%
survival_Pclass=df.groupby(['Sex','Pclass'])['Survived'].value_counts()

# %%
survival_Pclass
# Out:
# Sex     Pclass  Survived
# female  1       1            91
#                 0             3
#         2       1            70
#                 0             6
#         3       0            72
#                 1            72
# male    1       0            77
#                 1            45
#         2       0            91
#                 1            17
#         3       0           300
#                 1            47
# Name: count, dtype: int64

# %% [markdown]
# **First class survival rate higher.**

# %%
sns.countplot(
x='SibSp',hue='Survived',data=df,palette='Blues')

plt.title("SibSp vs Survival")


plt.show()

# %%
sns.countplot(
x='Embarked',hue='Survived',data=df,palette='Blues')

plt.title("Embarked vs Survival")


plt.show()

# %%
survival_Embarked=df.groupby(['Embarked'])['Survived'].value_counts()

# %%
survival_Embarked
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           219
# Name: count, dtype: int64

# %% [markdown]
# **Passenger survival varied by embarkation location.**
# ** Southampton

# %%
sns.countplot(
x='Title',hue='Survived',data=df,palette='Blues')

plt.title("Title vs Survival")


plt.show()

# %%
survival_Title=df.groupby('Title')['Survived'].value_counts()

# %%
survival_Title
# Out:
# Title   Survived
# Master  1            23
#         0            17
# Miss    1           130
#         0            55
# Mr      0           436
#         1            81
# Mrs     1           100
#         0            26
# Rare    0            15
#         1             8
# Name: count, dtype: int64

# %% [markdown]
# **Female-related titles had better survival rates.**

# %%
sns.countplot(
x='AgeGroup',hue='Survived',data=df,palette='Blues')

plt.title("AgeGroup vs Survival")


plt.show()

# %%
survival_AgeGroup=df.groupby('AgeGroup',observed=False)['Survived'].value_counts()

# %%
survival_AgeGroup
# Out:
# AgeGroup   Survived
# Child      1            40
#            0            29
# Teen       0            40
#            1            30
# Adult      0           330
#            1           175
# MiddleAge  0           133
#            1            92
# Senior     0            17
#            1             5
# Name: count, dtype: int64

# %%
sns.countplot(
x='FamilyStatus',hue='Survived',data=df,palette='Blues')

plt.title("FamilyStatus vs Survival")


plt.show()

# %%
survival_FamilyStatus=df.groupby('FamilyStatus',observed=False)['Survived'].value_counts()

# %%
survival_FamilyStatus
# Out:
# FamilyStatus  Survived
# Alone         0           374
#               1           163
# Family        1           179
#               0           175
# Name: count, dtype: int64

# %% [markdown]
# **Passengers with family survived more.**

# %%
sns.countplot(x='FareBand',hue='Survived',data=df,palette='Blues')

plt.title("FareBand vs Survival")


plt.show()

# %%
survival_FareBand=df.groupby('FareBand',observed=False)['Survived'].value_counts()

# %%
survival_FareBand
# Out:
# FareBand         Survived
# (-0.001, 7.91]   0           179
#                  1            44
# (7.91, 14.454]   0           156
#                  1            68
# (14.454, 31.0]   0           121
#                  1           101
# (31.0, 512.329]  1           129
#                  0            93
# Name: count, dtype: int64

# %% [markdown]
# **Passengers paying higher fares survived more.**

# %% [markdown]
# ## Target Analysis

# %%
sns.countplot(x='Survived',hue='Survived',legend=False,data=df,palette='Blues')

plt.title("Target Distribution")
plt.xlabel("Survived(0=No,1=Yes)")
plt.ylabel("Number of Passengers")

sns.set_style('whitegrid')

plt.show()

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# **More passengers did not survive than survived.**

# %%
for col in num_cols:
    plt.figure()
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show()

# %% [markdown]
# **Fare positively correlates with survival.**
#
# Higher fares were usually paid by First Class passengers
#
# **Pclass negatively correlates with survival.**

# %% [markdown]
# **Why?**
#
# First-class passengers had better cabin locations.
#
# Better access to lifeboats.
#
# Higher socioeconomic status.

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for col in ['Sex','Embarked','Title','FamilyStatus']:

    df[col]=\
    le.fit_transform(df[col])

# %%
#Correlation:

plt.figure(figsize=(10,6))

sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')

plt.show()
